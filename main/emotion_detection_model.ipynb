# %%
# !git clone https://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@github.com/nyctophile-1302/facial-emotion-detection.git
# Out:
# Cloning into 'facial-emotion-detection'...
# remote: Enumerating objects: 8135, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 8135 (delta 0), reused 15 (delta 0), pack-reused 8120
# Receiving objects: 100% (8135/8135), 58.19 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (3288/3288), done.

# %%
import numpy as np
import pandas as pd
import os, cv2

# %%
for dirname, _, filenames in os.walk('/content/facial-emotion-detection/data'):
  for filename in filenames:
    os.path.join(dirname, filename)

# %%
directory='/content/facial-emotion-detection/data'
dir_list=os.listdir(directory)
image_data_list=[]
labels=[]
emotions=[]
l=0
for data_dir in dir_list:
    data_list=os.listdir(directory+'/'+data_dir)
    for img in data_list:
        input_img=cv2.imread(directory+'/'+data_dir+'/'+img)
        input_img=cv2.resize(input_img,(48,48))
        image_data_list.append(input_img)
        labels.append(l)
    emotions.append(data_dir)
    l=l+1
img_data=np.array(image_data_list)
img_data=img_data/255
img_data.shape
# Out:
# (8450, 48, 48, 3)

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
num_classes=7
Y = keras.utils.to_categorical(labels, num_classes)
X_train, X_test, y_train, y_test = train_test_split(img_data, Y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_generator_with_aug = ImageDataGenerator(horizontal_flip = True,
                                              width_shift_range = 0.1,
                                              height_shift_range = 0.1)
data_generator_no_aug = ImageDataGenerator()

train_generator=data_generator_with_aug.flow(X_train,y_train)
validation_generator=data_generator_with_aug.flow(X_test,y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.metrics import categorical_accuracy

model=Sequential()
model.add(Conv2D(64,(3,3),padding="same",input_shape=(48,48,3),activation='relu'))
model.add(Conv2D(64,(3,3),padding="same",activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Conv2D(256,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.6))
model.add(Dense(num_classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit_generator(train_generator,epochs=100,validation_data=validation_generator)
# Out:
# Epoch 1/100
# <ipython-input-8-47cc38e7f8f4>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(train_generator,epochs=100,validation_data=validation_generator)
# 212/212 [==============================] - 24s 45ms/step - loss: 0.9418 - accuracy: 0.4896 - val_loss: 0.6933 - val_accuracy: 0.4787
# Epoch 2/100
# 212/212 [==============================] - 8s 39ms/step - loss: 0.7270 - accuracy: 0.5047 - val_loss: 0.6968 - val_accuracy: 0.4787
# Epoch 3/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.7155 - accuracy: 0.5099 - val_loss: 0.6956 - val_accuracy: 0.5213
# Epoch 4/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.7115 - accuracy: 0.5077 - val_loss: 0.6899 - val_accuracy: 0.4905
# Epoch 5/100
# 212/212 [==============================] - 8s 39ms/step - loss: 0.6560 - accuracy: 0.6271 - val_loss: 0.5675 - val_accuracy: 0.6864
# Epoch 6/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.5483 - accuracy: 0.7669 - val_loss: 0.4302 - val_accuracy: 0.8586
# Epoch 7/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.4624 - accuracy: 0.8259 - val_loss: 0.4424 - val_accuracy: 0.8006
# Epoch 8/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.3917 - accuracy: 0.8589 - val_loss: 0.3313 - val_accuracy: 0.8893
# Epoch 9/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.3629 - accuracy: 0.8515 - val_loss: 0.2604 - val_accuracy: 0.8763
# Epoch 10/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.2602 - accuracy: 0.9001 - val_loss: 0.1619 - val_accuracy: 0.9325
# Epoch 11/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.2097 - accuracy: 0.9198 - val_loss: 0.1281 - val_accuracy: 0.9550
# Epoch 12/100
# 212/212 [==============================] - 10s 46ms/step - loss: 0.1925 - accuracy: 0.9283 - val_loss: 0.1265 - val_accuracy: 0.9521
# Epoch 13/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.1878 - accuracy: 0.9299 - val_loss: 0.1076 - val_accuracy: 0.9609
# Epoch 14/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1862 - accuracy: 0.9296 - val_loss: 0.1098 - val_accuracy: 0.9621
# Epoch 15/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.1667 - accuracy: 0.9395 - val_loss: 0.1020 - val_accuracy: 0.9627
# Epoch 16/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.1526 - accuracy: 0.9447 - val_loss: 0.0874 - val_accuracy: 0.9716
# Epoch 17/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.1336 - accuracy: 0.9530 - val_loss: 0.0989 - val_accuracy: 0.9657
# Epoch 18/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1302 - accuracy: 0.9538 - val_loss: 0.0907 - val_accuracy: 0.9751
# Epoch 19/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1249 - accuracy: 0.9577 - val_loss: 0.1120 - val_accuracy: 0.9556
# Epoch 20/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.1213 - accuracy: 0.9580 - val_loss: 0.0665 - val_accuracy: 0.9805
# Epoch 21/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1117 - accuracy: 0.9595 - val_loss: 0.0945 - val_accuracy: 0.9686
# Epoch 22/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1057 - accuracy: 0.9624 - val_loss: 0.0730 - val_accuracy: 0.9722
# Epoch 23/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.1201 - accuracy: 0.9575 - val_loss: 0.0864 - val_accuracy: 0.9663
# Epoch 24/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0972 - accuracy: 0.9642 - val_loss: 0.0981 - val_accuracy: 0.9497
# Epoch 25/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1133 - accuracy: 0.9601 - val_loss: 0.0835 - val_accuracy: 0.9734
# Epoch 26/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1049 - accuracy: 0.9641 - val_loss: 0.0564 - val_accuracy: 0.9852
# Epoch 27/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0903 - accuracy: 0.9688 - val_loss: 0.0865 - val_accuracy: 0.9686
# Epoch 28/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.0963 - accuracy: 0.9669 - val_loss: 0.0595 - val_accuracy: 0.9876
# Epoch 29/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1061 - accuracy: 0.9633 - val_loss: 0.0447 - val_accuracy: 0.9817
# Epoch 30/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0837 - accuracy: 0.9725 - val_loss: 0.0736 - val_accuracy: 0.9751
# Epoch 31/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0948 - accuracy: 0.9682 - val_loss: 0.0475 - val_accuracy: 0.9852
# Epoch 32/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0810 - accuracy: 0.9689 - val_loss: 0.0776 - val_accuracy: 0.9627
# Epoch 33/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0846 - accuracy: 0.9709 - val_loss: 0.1554 - val_accuracy: 0.9408
# Epoch 34/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0804 - accuracy: 0.9714 - val_loss: 0.0702 - val_accuracy: 0.9763
# Epoch 35/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.1029 - accuracy: 0.9669 - val_loss: 0.0726 - val_accuracy: 0.9781
# Epoch 36/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0982 - accuracy: 0.9626 - val_loss: 0.0553 - val_accuracy: 0.9828
# Epoch 37/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0698 - accuracy: 0.9737 - val_loss: 0.0443 - val_accuracy: 0.9870
# Epoch 38/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0595 - accuracy: 0.9783 - val_loss: 0.0557 - val_accuracy: 0.9864
# Epoch 39/100
# 212/212 [==============================] - 9s 40ms/step - loss: 0.0690 - accuracy: 0.9769 - val_loss: 0.0424 - val_accuracy: 0.9893
# Epoch 40/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0786 - accuracy: 0.9720 - val_loss: 0.0606 - val_accuracy: 0.9876
# Epoch 41/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0679 - accuracy: 0.9787 - val_loss: 0.0636 - val_accuracy: 0.9870
# Epoch 42/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0822 - accuracy: 0.9725 - val_loss: 0.0544 - val_accuracy: 0.9852
# Epoch 43/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0647 - accuracy: 0.9774 - val_loss: 0.0554 - val_accuracy: 0.9858
# Epoch 44/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0687 - accuracy: 0.9762 - val_loss: 0.0539 - val_accuracy: 0.9834
# Epoch 45/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.0752 - accuracy: 0.9765 - val_loss: 0.0836 - val_accuracy: 0.9692
# Epoch 46/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0877 - accuracy: 0.9726 - val_loss: 0.0408 - val_accuracy: 0.9858
# Epoch 47/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0780 - accuracy: 0.9738 - val_loss: 0.0463 - val_accuracy: 0.9840
# Epoch 48/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0516 - accuracy: 0.9784 - val_loss: 0.0640 - val_accuracy: 0.9811
# Epoch 49/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0689 - accuracy: 0.9766 - val_loss: 0.0896 - val_accuracy: 0.9716
# Epoch 50/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0779 - accuracy: 0.9763 - val_loss: 0.1665 - val_accuracy: 0.9124
# Epoch 51/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0616 - accuracy: 0.9778 - val_loss: 0.0368 - val_accuracy: 0.9876
# Epoch 52/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0513 - accuracy: 0.9815 - val_loss: 0.1083 - val_accuracy: 0.9692
# Epoch 53/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0912 - accuracy: 0.9713 - val_loss: 0.0799 - val_accuracy: 0.9793
# Epoch 54/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0668 - accuracy: 0.9784 - val_loss: 0.0470 - val_accuracy: 0.9805
# Epoch 55/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0659 - accuracy: 0.9769 - val_loss: 0.0651 - val_accuracy: 0.9858
# Epoch 56/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0551 - accuracy: 0.9802 - val_loss: 0.0296 - val_accuracy: 0.9935
# Epoch 57/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0531 - accuracy: 0.9817 - val_loss: 0.0417 - val_accuracy: 0.9828
# Epoch 58/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0470 - accuracy: 0.9831 - val_loss: 0.0442 - val_accuracy: 0.9870
# Epoch 59/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0677 - accuracy: 0.9784 - val_loss: 0.0402 - val_accuracy: 0.9893
# Epoch 60/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0694 - accuracy: 0.9793 - val_loss: 0.0483 - val_accuracy: 0.9876
# Epoch 61/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0599 - accuracy: 0.9809 - val_loss: 0.0966 - val_accuracy: 0.9698
# Epoch 62/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0611 - accuracy: 0.9771 - val_loss: 0.0597 - val_accuracy: 0.9769
# Epoch 63/100
# 212/212 [==============================] - 8s 40ms/step - loss: 0.0526 - accuracy: 0.9793 - val_loss: 0.0476 - val_accuracy: 0.9811
# Epoch 64/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0552 - accuracy: 0.9809 - val_loss: 0.1022 - val_accuracy: 0.9828
# Epoch 65/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0499 - accuracy: 0.9834 - val_loss: 0.0525 - val_accuracy: 0.9876
# Epoch 66/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0526 - accuracy: 0.9827 - val_loss: 0.0342 - val_accuracy: 0.9947
# Epoch 67/100
# 212/212 [==============================] - 8s 39ms/step - loss: 0.0517 - accuracy: 0.9836 - val_loss: 0.0569 - val_accuracy: 0.9876
# Epoch 68/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0378 - accuracy: 0.9843 - val_loss: 0.0520 - val_accuracy: 0.9899
# Epoch 69/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0585 - accuracy: 0.9809 - val_loss: 0.0753 - val_accuracy: 0.9675
# Epoch 70/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0684 - accuracy: 0.9788 - val_loss: 0.0656 - val_accuracy: 0.9888
# Epoch 71/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0314 - accuracy: 0.9868 - val_loss: 0.1752 - val_accuracy: 0.9740
# Epoch 72/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0588 - accuracy: 0.9840 - val_loss: 0.0858 - val_accuracy: 0.9846
# Epoch 73/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0614 - accuracy: 0.9808 - val_loss: 0.0646 - val_accuracy: 0.9852
# Epoch 74/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0715 - accuracy: 0.9814 - val_loss: 0.0406 - val_accuracy: 0.9899
# Epoch 75/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0517 - accuracy: 0.9831 - val_loss: 0.0548 - val_accuracy: 0.9876
# Epoch 76/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0478 - accuracy: 0.9851 - val_loss: 0.0403 - val_accuracy: 0.9917
# Epoch 77/100
# 212/212 [==============================] - 10s 46ms/step - loss: 0.0617 - accuracy: 0.9802 - val_loss: 0.0492 - val_accuracy: 0.9834
# Epoch 78/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.0416 - accuracy: 0.9843 - val_loss: 0.0458 - val_accuracy: 0.9888
# Epoch 79/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0298 - accuracy: 0.9902 - val_loss: 0.0512 - val_accuracy: 0.9882
# Epoch 80/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0815 - accuracy: 0.9753 - val_loss: 0.0489 - val_accuracy: 0.9840
# Epoch 81/100
# 212/212 [==============================] - 9s 45ms/step - loss: 0.0407 - accuracy: 0.9833 - val_loss: 0.0381 - val_accuracy: 0.9899
# Epoch 82/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.0377 - val_accuracy: 0.9899
# Epoch 83/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0408 - accuracy: 0.9852 - val_loss: 0.0501 - val_accuracy: 0.9893
# Epoch 84/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0528 - accuracy: 0.9811 - val_loss: 0.0435 - val_accuracy: 0.9882
# Epoch 85/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.0396 - val_accuracy: 0.9888
# Epoch 86/100
# 212/212 [==============================] - 8s 36ms/step - loss: 0.0442 - accuracy: 0.9864 - val_loss: 0.0445 - val_accuracy: 0.9905
# Epoch 87/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0627 - accuracy: 0.9842 - val_loss: 0.0866 - val_accuracy: 0.9710
# Epoch 88/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0856 - accuracy: 0.9757 - val_loss: 0.0998 - val_accuracy: 0.9609
# Epoch 89/100
# 212/212 [==============================] - 9s 43ms/step - loss: 0.0434 - accuracy: 0.9852 - val_loss: 0.0501 - val_accuracy: 0.9888
# Epoch 90/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0401 - accuracy: 0.9846 - val_loss: 0.1122 - val_accuracy: 0.9840
# Epoch 91/100
# 212/212 [==============================] - 9s 42ms/step - loss: 0.0365 - accuracy: 0.9877 - val_loss: 0.0415 - val_accuracy: 0.9905
# Epoch 92/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0464 - accuracy: 0.9845 - val_loss: 0.1760 - val_accuracy: 0.9604
# Epoch 93/100
# 212/212 [==============================] - 8s 37ms/step - loss: 0.0539 - accuracy: 0.9837 - val_loss: 0.0446 - val_accuracy: 0.9876
# Epoch 94/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.0602 - val_accuracy: 0.9905
# Epoch 95/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0562 - accuracy: 0.9836 - val_loss: 0.0959 - val_accuracy: 0.9793
# Epoch 96/100
# 212/212 [==============================] - 8s 38ms/step - loss: 0.0409 - accuracy: 0.9882 - val_loss: 0.0499 - val_accuracy: 0.9905
# Epoch 97/100
# 212/212 [==============================] - 9s 40ms/step - loss: 0.0589 - accuracy: 0.9831 - val_loss: 0.0596 - val_accuracy: 0.9941
# Epoch 98/100
# 212/212 [==============================] - 10s 46ms/step - loss: 0.0426 - accuracy: 0.9879 - val_loss: 0.0766 - val_accuracy: 0.9828
# Epoch 99/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0384 - accuracy: 0.9880 - val_loss: 0.0238 - val_accuracy: 0.9935
# Epoch 100/100
# 212/212 [==============================] - 9s 41ms/step - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.0463 - val_accuracy: 0.9905

# %%
import matplotlib.pyplot as plt
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
results = model.predict(X_test)
predicted_classes = np.argmax(results, axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), predicted_classes)
# Out:
# 53/53 [==============================] - 1s 5ms/step

# %%
label = ['contempt','surprise']
labels = {0 : 'contempt', 1 :'surprise'}

# %%
cm_df = pd.DataFrame(cm, index = label,
                     columns = label)

# %%
final_cm = cm_df

# %%
import seaborn as sns

plt.figure(figsize = (5,5))
sns.heatmap(final_cm, annot = True,cmap='Greys',cbar=False,linewidth=2,fmt='d')
plt.title('CNN Emotion Classify')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
import random
from glob import glob
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
def choose_image_and_predict():
    folder_choice = (random.choice(dir_list))
    images = glob(directory + '/'+ folder_choice+'/*')
    img_choice = (random.choice(images))

    img = image.load_img(img_choice, target_size=(48, 48))
    img = image.img_to_array(img)
    plt.imshow(img / 255.)
    x = preprocess_input(np.expand_dims(img.copy(), axis=0))
    pred_class = model.predict(x)
    pred = model.predict(x)
    label=np.argmax(pred,axis=1)[0]
    print("Actual class:", folder_choice)
    print("Predicted Class:" , labels[label])

choose_image_and_predict()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Actual class: surprise
# Predicted Class: surprise
